# %%
# !pip install -q git+https://github.com/pan-webis-de/pan-code.git#subdirectory=clef25/generative-authorship-verification/pan25_genai_baselines
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 84.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y torchvision
# Out:
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128

# %%
import os
os.environ["HF_TOKEN"] = ""

# %%
# !mkdir -p /kaggle/working/output_binoculars && pan25-baseline binoculars \
    --observer tiiuae/falcon-7b \
    --performer tiiuae/falcon-7b-instruct \
    --quantize 4 \
    /kaggle/input/datasets/pan25-generative-ai-detection-task1-train/pan25-generative-ai-detection-task1-train/val.jsonl \
    /kaggle/working/output_binoculars
# Out:
# config.json: 1.05kB [00:00, 3.02MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 17.7kB [00:00, 32.3MB/s]
# ...
# Fetching 2 files: 100%|███████████████████████████| 2/2 [01:03<00:00, 31.89s/it]
# Download complete: 100%|███████████████████| 14.4G/14.4G [01:03<00:00, 96.1MB/s]
# Loading weights:   0%|                                  | 0/196 [00:00<?, ?it/s]
# Loading weights:   1%| | 1/196 [00:00<00:00, 6223.00it/s, Materializing param=lm
# Loading weights:   1%| | 1/196 [00:00<00:00, 1409.85it/s, Materializing param=lm
# Loading weights:   1%| | 2/196 [00:00<00:18, 10.57it/s, Materializing param=lm_h
# Loading weights:   1%| | 2/196 [00:00<00:18, 10.57it/s, Materializing param=tran
# Loading weights:   1%| | 2/196 [00:00<00:18, 10.57it/s, Materializing param=tran
# Loading weights:   2%| | 3/196 [00:00<00:18, 10.57it/s, Materializing param=tran
# Loading weights:   2%| | 3/196 [00:00<00:18, 10.57it/s, Materializing param=tran
# ...
